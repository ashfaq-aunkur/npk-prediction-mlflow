# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import joblib

# %%
print(os.listdir())
# Out:
# ['sample_dataset.ipynb']

# %%
df = pd.read_csv("../datasets/sample-dataset-npks - Sheet1.csv")
df.head()
# Out:
#       id  soil_test_land_id aunkur_id  value_N  value_P  value_K  value_E  \
# 0  54518              31652      A012      832     13.0       61     0.26
# 1  54517              31651      A012      832     13.0       61     0.26
# 2  54516              31650      A012      832     13.0       61     0.26
# 3  54515              31649      A012      832     13.0       61     0.26
# 4  54514              31648      A012      835     13.0       61     0.25
#
#    value_Ph  value_M  value_T  value_zn  value_soc  value_boron
# 0      4.54    25.40    18.02      0.71       1.64         0.29
# 1      4.80    25.44    17.84      0.71       1.60         0.30
# 2      5.56    25.46    17.76      0.73       1.51         0.30
# 3      6.88    25.62    17.75      0.87       1.35         0.30
# 4      6.96    26.05    17.70      0.88       1.35         0.30

# %%
df = df[["value_N", "value_E", "value_Ph", "target_n"]]
