# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import joblib

# %%
df = pd.read_csv("../datasets/BAU_10AEZ_Nutrients_Sensitivity_Test - Sheet3.csv")
df.head()
# Out:
#    AEZ No  E_5P2  pH_5P2  N_5P2  P_5P2  K_5P2
# 0       1   0.28     6.4   20.0   27.0   67.0
# 1       1   0.26     6.8   18.0   25.0   62.0
# 2       1   0.34     6.8   24.0   32.0   81.0
# 3       1   0.58     7.1   42.0   57.0  141.0
# 4       1   0.27     6.7   19.0   26.0   65.0
